# %%
a=17
b=3
a+=b
print(a)
# Out:
# 20

# %%
a=75
b=7
a-=b
print(a)
# Out:
# 68

# %%
a=45
b=8
a*=b
print(a)
# Out:
# 360

# %%
a=33
b=8
a/=b
print(a)
# Out:
# 4.125

# %%
a=66
b=88
a**=b
print(a)
# Out:
# 13178510522716872655319238066254261900640428904597084991084305835847338167564624007457480583106103029669005706620759237604335830854305162036310315064928969424896

# %%
a=99
b=22
a//=b
print(a)
# Out:
# 4

# %%
a=865
b=10000
a%=b
print(a)
# Out:
# 865

# %%
a=6789
b=4547
print(a==b)
# Out:
# False

# %%
a=6789
b=4547
print(a!=b)
# Out:
# True

# %%
a=70
b=60
print(a>=b)
# Out:
# True

# %%
a=70
b=60
print(a<=b)
# Out:
# False

# %%
x=99
print(x>98 and x<100)
# Out:
# True

# %%
x=99
print(x>98 and x>100)
# Out:
# True

# %%
x=99
print(x>66 or x>77)
# Out:
# True

# %%
x=99
print(x<3 or x>101)
# Out:
# False

# %%
x=214
print(not(x>210 or x>220))
print(not(x>210 or x<220))
# Out:
# False
# False

# %%
x1=2222
x2=1111
print(x2 is x1)
# Out:
# False

# %%
x1=2222
x2=1111
print(x2 is not x1)
# Out:
# True

# %%
print(9999&8888)
# Out:
# 8712

# %%
print(9999 & 8888)
# Out:
# 8712

# %%
print(8888 | 9999)
# Out:
# 10175

# %%
print(9999^8888)
# Out:
# 1463

# %%
print(9999 << 8888)
# Out:
# ...

# %%
print(9999 << 8888)
# Out:
# ...

# %%
(~7)
# Out:
# -8
